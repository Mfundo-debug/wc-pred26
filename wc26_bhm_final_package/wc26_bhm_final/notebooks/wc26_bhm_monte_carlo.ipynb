# %% [markdown]
# # WC26 Bayesian Hierarchical Model + Monte Carlo Simulation

# %% [markdown]
# This notebook accompanies the package. It loads packaged model outputs and documents the PyMC BHM workflow.

# %%
import pandas as pd
from pathlib import Path
ROOT=Path('..')
teams=pd.read_csv(ROOT/'data/teams.csv')
live=pd.read_csv(ROOT/'data/verified_live_results.csv')
teams.head(), live

# %% [markdown]
# ## PyMC diagnostics

# %%
pd.read_csv(ROOT/'outputs/pymc_diagnostics_summary.csv')

# %% [markdown]
# ## Simulation outputs

# %%
champ=pd.read_csv(ROOT/'outputs/champion_probabilities.csv')
stage=pd.read_csv(ROOT/'outputs/stage_probability_matrix.csv')
pairs=pd.read_csv(ROOT/'outputs/final_match_probabilities.csv')
champ.head(12), pairs.head(10)

# %% [markdown]
# ## Visual dashboard

# %%
from IPython.display import Image, display
display(Image(filename=str(ROOT/'figures/dashboard_main.png')))
display(Image(filename=str(ROOT/'figures/champion_probabilities.png')))
display(Image(filename=str(ROOT/'figures/stage_probability_matrix.png')))

# %% [markdown]
# ## Rerun instructions
# Run `streamlit run streamlit_app/app.py` or open `dashboard/index.html`. Use `src/00_fetch_fjelstul_worldcup_data.py` to download full Fjelstul CSVs when online.
